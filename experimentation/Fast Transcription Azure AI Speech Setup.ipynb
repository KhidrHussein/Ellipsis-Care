# %%
import os
import requests
from dotenv import load_dotenv
load_dotenv()

# Define the endpoint and subscription key
url = f"https://eastus.api.cognitive.microsoft.com/speechtotext/transcriptions:transcribe?api-version=2024-05-15-preview"
subscription_key = os.getenv('SUBSCRIPTION_KEY')

# %%
# Set up headers with your subscription key
# subscription_key = 'YourSubscriptionKey'
headers = {
    'Ocp-Apim-Subscription-Key': subscription_key,
    'Accept': 'application/json'
}

# Define the files and data for the request
files = {
    'audio': open('/Users/mac/Downloads/2024-08-28 13.18.47.ogg', 'rb')  # Replace with your audio file path
}
data = {
    'definition': '''
    {
        "locales": ["en-US"],
        "profanityFilterMode": "Masked"
    }
    '''
}
# "channels": [0, 1]

# %%
# Make the POST request
response = requests.post(url, headers=headers, files=files, data=data)

# %%
# Check the response
if response.status_code == 200:
    print('Success!')
    print(response.json())
    print(response.json()['combinedPhrases'][0]['text'])
else:
    print('Error:', response.status_code)
    print(response.text)
# Out:
# Success!
# {'duration': 408893, 'combinedPhrases': [{'text': "OK, So what we discussed, we tried to break things down into different points and the first thing that we discussed during the meeting was the preliminary stages for the competition, right. So that's the idea basically is you have 500, let's say 50 people that are interested in participating in the competition and then there is a preliminary stage to shortlist the five people that will actually compete, right, so. The first the idea around it is to use data structures and algorithms. Basically DSC in whatever language you like you you any language of your choice basically to do the test. I think I already shared that on the group also. So what what is happening is that for for for example we there'll be like 2 questions. The idea basically is you have two questions for DSC physic introductory stuff just to test your. Algorithmic thinking and then the use of the programming languages so that we don't have you know people that OK, you know the boys around maybe a competition that you could win some money and stuff like that doesn't want to apply. And even from the idea of having a preliminary stage, definitely some people will drop off because you know not everyone wants to put that commitment into everything. So something should just apply because of fear of missing out or something. But you don't have really have the. The plan to push for it to the end. So preliminary stage with us basically to get out top five serious people for the final stage right? And then there will be two DSA questions. They could be on graphs like I already mentioned, depth first search algorithm, breadth first search algorithm or just algorithm. And those algorithm basically that has to do with no shortest paths and fastest, fastest paths, graphs, maps and you know things around maze that are related to the competition, algorithms that you most likely apply when building your model for the car to solve the maze. So that's one thing. And then there'll be other questions along the line also on robotics. So maybe things on Ross, things on. You know basic questions on robotics, on maybe component in terms of speed like racing, things to take notes, those things that you know that are important for anybody that is into robotics to participate in that challenge should know to actually like be successful in that challenge. So there'll be questions and the the idea, the main talking point around it was what platform to host it on and I know with Hacker rank you can host TSA challenges, right? On Hacker Rank, I believe you should also be able to multiple choice questions because I I've taken some tests and there are some like that have obituary questions like match related and stuff. So you should be able to set your own questions and answers. So if there are other platforms that we have in mind too. So that's one of the action points like you know check through other platforms apart from Hacker Rank that can be used for this. And then the next thing that we had we talked about which is a way we also need to research on right. So it's another actionable point is. On the material to be used, the material to be used. So for the maze now, are we using something like wood or cardboard? We know cardboard might be very light in terms of collision. So let's say somebody hits like a car while trying to navigate the maze, hit one of the walls, right? Does the whole maze crumble? Because the structure is not so strong. So we need something that is light. But also still rigid enough to handle collision by the cars. And of course the cars will not be so heavy. So let's say Max of five kg or maybe at most 7 kg. I don't think it will get to 7 kg based on all the components yet. So if a 5 kg car, you know hit something, something that will not just break down the whole structure of the maze, I believe would have watched the videos I shared, right. So when there's a collision, it's not something that will crumble the whole st ...
# OK, So what we discussed, we tried to break things down into different points and the first thing that we discussed during the meeting was the preliminary stages for the competition, right. So that's the idea basically is you have 500, let's say 50 people that are interested in participating in the competition and then there is a preliminary stage to shortlist the five people that will actually compete, right, so. The first the idea around it is to use data structures and algorithms. Basically DSC in whatever language you like you you any language of your choice basically to do the test. I think I already shared that on the group also. So what what is happening is that for for for example we there'll be like 2 questions. The idea basically is you have two questions for DSC physic introductory stuff just to test your. Algorithmic thinking and then the use of the programming languages so that we don't have you know people that OK, you know the boys around maybe a competition that you could win some money and stuff like that doesn't want to apply. And even from the idea of having a preliminary stage, definitely some people will drop off because you know not everyone wants to put that commitment into everything. So something should just apply because of fear of missing out or something. But you don't have really have the. The plan to push for it to the end. So preliminary stage with us basically to get out top five serious people for the final stage right? And then there will be two DSA questions. They could be on graphs like I already mentioned, depth first search algorithm, breadth first search algorithm or just algorithm. And those algorithm basically that has to do with no shortest paths and fastest, fastest paths, graphs, maps and you know things around maze that are related to the competition, algorithms that you most likely apply when building your model for the car to solve the maze. So that's one thing. And then there'll be other questions along the line also on robotics. So maybe things on Ross, things on. You know basic questions on robotics, on maybe component in terms of speed like racing, things to take notes, those things that you know that are important for anybody that is into robotics to participate in that challenge should know to actually like be successful in that challenge. So there'll be questions and the the idea, the main talking point around it was what platform to host it on and I know with Hacker rank you can host TSA challenges, right? On Hacker Rank, I believe you should also be able to multiple choice questions because I I've taken some tests and there are some like that have obituary questions like match related and stuff. So you should be able to set your own questions and answers. So if there are other platforms that we have in mind too. So that's one of the action points like you know check through other platforms apart from Hacker Rank that can be used for this. And then the next thing that we had we talked about which is a way we also need to research on right. So it's another actionable point is. On the material to be used, the material to be used. So for the maze now, are we using something like wood or cardboard? We know cardboard might be very light in terms of collision. So let's say somebody hits like a car while trying to navigate the maze, hit one of the walls, right? Does the whole maze crumble? Because the structure is not so strong. So we need something that is light. But also still rigid enough to handle collision by the cars. And of course the cars will not be so heavy. So let's say Max of five kg or maybe at most 7 kg. I don't think it will get to 7 kg based on all the components yet. So if a 5 kg car, you know hit something, something that will not just break down the whole structure of the maze, I believe would have watched the videos I shared, right. So when there's a collision, it's not something that will crumble the whole structure and. We can check the materials that are us ...
